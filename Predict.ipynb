# %% [markdown]
# # 机器学习实现预测部分代码

# %% [markdown]
# #### 导入包

# %%
import matplotlib
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split  # 划分训练集和测试集
from sklearn.neural_network import MLPRegressor  # 多层线性回归
from sklearn.preprocessing import StandardScaler  # 对数据进行标准化
import matplotlib.pyplot as plt # 绘制预测曲线和真实曲线，分析拟合结果
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error  # MSE, MAPE
import os

# %% [markdown]
# #### 预测函数，实现思路是通过构造一个含有2个隐藏层的BP神经网络进行回归拟合。
# #### 特征属性有：
# #### average_car_spacing(平均车间距)，average_car_length(平均车长)，occupancy(占有率)
# #### 标签属性：（即需要进行预测的属性）
# #### total_traffic(总车流量)，average_speed(平均车速)
# #### 上述值均可从预处理后的数据中提取作为训练集和测试集，使用BP神经网络进行模型训练，并打印出平均预测准确率（bp.score）和MSE,RMSE,MAPE(平均预测偏差率)三个指标[total_traffic,average_speed]。详细代码如下。

# %%
def Predict(number, lane, min_time):
    data = np.array(pd.read_excel('.\\' + str(min_time) + 'min的数据' + '\\' + str(number) + '_' + str(lane) + '.xlsx'))
    # 导入数据集
    dataMat = np.array(data)
    train_data = dataMat[:, 2:5]  # 特征集
    train_target = dataMat[:, 5:7]  # 标签集

    x_train, x_test, y_train, y_test = train_test_split(train_data, train_target, test_size=0.25, random_state=0)
    # train_data：所要划分的样本特征集
    # train_target：所要划分的样本结果
    # test_size：测试集占全体样本比重，如果是整数的话就是样本的数量
    # random_state：是随机数的种子。

    # 数据标准化
    scaler = StandardScaler()  # 标准化转换

    x_test_Standard = scaler.fit_transform(x_test)  # 转换数据集
    x_train_Standard = scaler.fit_transform(x_train)  # 转换数据集
    y_test_Standard = scaler.fit_transform(y_test)  # 转换数据集
    y_train_Standard = scaler.fit_transform(y_train)  # 转换数据集

    bp = MLPRegressor(solver='lbfgs', alpha=0.0001, hidden_layer_sizes=(5, 3), random_state=1, max_iter=3000)
    bp.fit(x_train_Standard, y_train_Standard) #使用构建的BP神经网络进行训练

    y_predict_Standard = bp.predict(x_test_Standard)
    y_predict = scaler.inverse_transform(y_predict_Standard)

    print(str(number) + '_' + str(lane) + '在最小时间戳为' + str(min_time) + '时:')

    print('数据预测平均准确度:' + str(bp.score(x_test_Standard, y_test_Standard)))
    print('MSE:' + str(
        np.around(mean_squared_error(y_test_Standard, y_predict_Standard, multioutput='raw_values'), decimals=3)))
    print('RMSE:' + str(
        np.around(np.sqrt(mean_squared_error(y_test_Standard, y_predict_Standard, multioutput='raw_values')),
                  decimals=3)))
    print('MAPE:' + str(
        np.around(mean_absolute_percentage_error(y_test_Standard, y_predict_Standard, multioutput='raw_values'),
                  decimals=3)))
    print('\n')



#   在测试集上绘制出真实曲线和预测曲线，分析预测值和真实值的拟合程度，保存图像，便于直观分析拟合效果
    matplotlib.use('Agg')
    y_label = ['total_traffic', 'average_speed']
    plt.rcParams['font.family'] = ['Fangsong']
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(15, 12), dpi=500)

    for i in range(0, 2):
        # print(y_test_Standard)
        x = np.arange(0, min(y_test_Standard.shape[0], 500), 1)
        y1 = y_test_Standard[0:min(y_test_Standard.shape[0], 500), i]
        y2 = y_predict_Standard[0:min(y_predict_Standard.shape[0], 500), i]
        plt.subplot(2, 1, i+1)
        plt.plot(x, y1, color='orange')  # 橙色线为真实曲线
        plt.plot(x, y2, color='dodgerblue')
        plt.xlabel("时间戳数")
        plt.ylabel(y_label[i])
        plt.title(y_label[i] + '拟合曲线与真实曲线的比较')

    # 保存图像
    dirs = '.\\预测分析图像\\' + str(min_time) + 'min的数据' + '\\'
    if not os.path.exists(dirs):
        os.makedirs(dirs)  # 创建文件夹存放图像
    plt.savefig('.\\预测分析图像\\' + str(min_time) + 'min的数据' + '\\' + str(number) + '_' + str(
        lane) + '拟合曲线与真实曲线的比较.jpg')

    plt.close()

# %% [markdown]
# #### 对不同设备，不同车道采集的数据集按不同时间戳进行预测，在测试集上分析预测结果和拟合图像。

# %%
if __name__ == '__main__':
    for number in range(75, 85):
        for lane in range(1, 3):
            for min_time in [5, 30, 60, 120, 1440]:
                Predict(number, lane, min_time)
# Out:
# 75_1在最小时间戳为5时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40746961e+10 2.77793073e+10]
#
#
# 75_1在最小时间戳为30时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40465662e+10 2.77650935e+10]
#
#
# 75_1在最小时间戳为60时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40128559e+10 2.77480413e+10]
#
#
# 75_1在最小时间戳为120时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40128559e+10 2.77480413e+10]
#
#
# 75_1在最小时间戳为1440时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40128559e+10 2.77480413e+10]
#
#
# 75_2在最小时间戳为5时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40746961e+10 2.77793073e+10]
#
#
# 75_2在最小时间戳为30时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40465662e+10 2.77650935e+10]
#
#
# 75_2在最小时间戳为60时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40128559e+10 2.77480413e+10]
#
#
# 75_2在最小时间戳为120时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40128559e+10 2.77480413e+10]
#
#
# 75_2在最小时间戳为1440时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0. 0.]
# MAPE:[2.40128559e+10 2.77480413e+10]
#
#
# 76_1在最小时间戳为5时:
# 数据预测平均准确度:0.4372338557979316
# MSE:[0.137 0.989]
# RMSE:[0.37  0.994]
# MAPE:[0.837 1.215]
#
#
# 76_1在最小时间戳为30时:
# 数据预测平均准确度:0.5484695524165001
# MSE:[0.18  0.723]
# RMSE:[0.425 0.85 ]
# MAPE:[ 1.378 13.406]
#
#
# 76_1在最小时间戳为60时:
# 数据预测平均准确度:0.8684965844026715
# MSE:[0.061 0.202]
# RMSE:[0.247 0.449]
# MAPE:[0.95  5.113]
#
#
# 76_1在最小时间戳为120时:
# 数据预测平均准确度:0.8772667144573177
# MSE:[0.024 0.221]
# RMSE:[0.156 0.47 ]
# MAPE:[0.508 4.182]
#
#
# 76_1在最小时间戳为1440时:
# 数据预测平均准确度:0.9691208212052032
# MSE:[0.028 0.034]
# RMSE:[0.168 0.183]
# MAPE:[3.834 2.261]
#
#
# 76_2在最小时间戳为5时:
# 数据预测平均准确度:0.9513356509903277
# MSE:[0.06  0.038]
# RMSE:[0.244 0.194]
# MAPE:[6.196 1.218]
#
#
# 76_2在最小时间戳为30时:
# 数据预测平均准确度:0.9339256209328666
# MSE:[0.022 0.11 ]
# RMSE:[0.147 0.332]
# MAPE:[1.272 0.488]
#
#
# 76_2在最小时间戳为60时:
# 数据预测平均准确度:0.9468135639158417
# MSE:[0.033 0.073]
# RMSE:[0.182 0.271]
# MAPE:[0.887 0.674]
#
#
# 76_2在最小时间戳为120时:
# 数据预测平均准确度:0.9586136578985646
# MSE:[0.021 0.061]
# RMSE:[0.146 0.248]
# MAPE:[0.399 0.569]
#
#
# 76_2在最小时间戳为1440时:
# 数据预测平均准确度:0.9790720204956103
# MSE:[0.01  0.032]
# RMSE:[0.101 0.178]
# MAPE:[2.247 2.341]
#
#
# 77_1在最小时间戳为5时:
# 数据预测平均准确度:0.8433357295101824
# MSE:[0.05  0.263]
# RMSE:[0.224 0.513]
# MAPE:[0.683 1.523]
#
#
# 77_1在最小时间戳为30时:
# 数据预测平均准确度:0.5690716821726474
# MSE:[0.158 0.703]
# RMSE:[0.398 0.839]
# MAPE:[5.308 2.175]
#
#
# 77_1在最小时间戳为60时:
# 数据预测平均准确度:0.754047420118888
# MSE:[0.041 0.451]
# RMSE:[0.203 0.671]
# MAPE:[0.972 3.833]
#
#
# 77_1在最小时间戳为120时:
# 数据预测平均准确度:0.6029143260562378
# MSE:[0.293 0.501]
# RMSE:[0.541 0.708]
# MAPE:[1.219 2.649]
#
#
# 77_1在最小时间戳为1440时:
# 数据预测平均准确度:0.9541819996513505
# MSE:[0.025 0.067]
# RMSE:[0.157 0.259]
# MAPE:[0.398 2.367]
#
#
# 77_2在最小时间戳为5时:
# 数据预测平均准确度:0.956852973386435
# MSE:[0.039 0.047]
# RMSE:[0.197 0.218]
# MAPE:[0.56  1.238]
#
#
# 77_2在最小时间戳为30时:
# 数据预测平均准确度:0.8716044813803916
# MSE:[0.018 0.239]
# RMSE:[0.135 0.488]
# MAPE:[0.515 1.104]
#
#
# 77_2在最小时间戳为60时:
# 数据预测平均准确度:0.8511807808608338
# MSE:[0.021 0.276]
# RMSE:[0.146 0.526]
# MAPE:[0.351 8.003]
#
#
# 77_2在最小时间戳为120时:
# 数据预测平均准确度:0.9333980336728669
# MSE:[0.01  0.123]
# RMSE:[0.099 0.351]
# MAPE:[0.483 1.259]
#
#
# 77_2在最小时间戳为1440时:
# 数据预测平均准确度:0.9827398029485038
# MSE:[0.005 0.029]
# RMSE:[0.073 0.171]
# MAPE:[1.435 2.231]
#
#
# 78_1在最小时间戳为5时:
# 数据预测平均准确度:0.7879768161152055
# MSE:[0.074 0.35 ]
# RMSE:[0.273 0.591]
# MAPE:[5.954 4.765]
#
#
# 78_1在最小时间戳为30时:
# 数据预测平均准确度:0.7569579534270099
# MSE:[0.061 0.425]
# RMSE:[0.247 0.652]
# MAPE:[0.924 1.735]
#
#
# 78_1在最小时间戳为60时:
# 数据预测平均准确度:0.5742056523208681
# MSE:[0.096 0.755]
# RMSE:[0.31  0.869]
# MAPE:[1.63  3.322]
#
#
# 78_1在最小时间戳为120时:
# 数据预测平均准确度:0.6222205361519859
# MSE:[0.156 0.599]
# RMSE:[0.395 0.774]
# MAPE:[ 1.511 11.675]
#
#
# 78_1在最小时间戳为1440时:
# 数据预测平均准确度:0.9695135506690435
# MSE:[0.033 0.028]
# RMSE:[0.183 0.166]
# MAPE:[1.13  1.903]
#
#
# 78_2在最小时间戳为5时:
# 数据预测平均准确度:0.9502400897556109
# MSE:[0.07 0.03]
# RMSE:[0.264 0.173]
# MAPE:[0.828 0.703]
#
#
# 78_2在最小时间戳为30时:
# 数据预测平均准确度:0.9089697477176488
# MSE:[0.068 0.114]
# RMSE:[0.262 0.337]
# MAPE:[1.393 0.578]
#
#
# 78_2在最小时间戳为60时:
# 数据预测平均准确度:0.9483292553542517
# MSE:[0.029 0.074]
# RMSE:[0.171 0.272]
# MAPE:[1.017 0.546]
#
#
# 78_2在最小时间戳为120时:
# 数据预测平均准确度:0.9659530816976953
# MSE:[0.015 0.053]
# RMSE:[0.122 0.231]
# MAPE:[0.772 1.386]
#
#
# 78_2在最小时间戳为1440时:
# 数据预测平均准确度:0.9572539941718281
# MSE:[0.032 0.054]
# RMSE:[0.178 0.232]
# MAPE:[0.816 3.163]
#
#
# 79_1在最小时间戳为5时:
# 数据预测平均准确度:0.9256385841060104
# MSE:[0.117 0.032]
# RMSE:[0.342 0.178]
# MAPE:[1.588 0.408]
#
#
# 79_1在最小时间戳为30时:
# 数据预测平均准确度:0.8952053690893462
# MSE:[0.096 0.113]
# RMSE:[0.31  0.337]
# MAPE:[0.619 0.996]
#
#
# 79_1在最小时间戳为60时:
# 数据预测平均准确度:0.9245703004093417
# MSE:[0.085 0.065]
# RMSE:[0.292 0.256]
# MAPE:[0.65  1.023]
#
#
# 79_1在最小时间戳为120时:
# 数据预测平均准确度:0.958368634314263
# MSE:[0.035 0.049]
# RMSE:[0.186 0.221]
# MAPE:[0.591 0.528]
#
#
# 79_1在最小时间戳为1440时:
# 数据预测平均准确度:0.9188335160143182
# MSE:[0.052 0.11 ]
# RMSE:[0.228 0.332]
# MAPE:[0.902 1.89 ]
#
#
# 79_2在最小时间戳为5时:
# 数据预测平均准确度:0.9573508595921746
# MSE:[0.057 0.028]
# RMSE:[0.239 0.168]
# MAPE:[0.143 0.073]
#
#
# 79_2在最小时间戳为30时:
# 数据预测平均准确度:0.8027224588961585
# MSE:[0.235 0.159]
# RMSE:[0.485 0.399]
# MAPE:[13.52   1.655]
#
#
# 79_2在最小时间戳为60时:
# 数据预测平均准确度:0.7934398613637468
# MSE:[0.236 0.177]
# RMSE:[0.485 0.421]
# MAPE:[1.16  1.931]
#
#
# 79_2在最小时间戳为120时:
# 数据预测平均准确度:0.8190205021196111
# MSE:[0.229 0.133]
# RMSE:[0.479 0.365]
# MAPE:[2.052 0.842]
#
#
# 79_2在最小时间戳为1440时:
# 数据预测平均准确度:0.8422101199076388
# MSE:[0.134 0.182]
# RMSE:[0.366 0.426]
# MAPE:[1.001 2.099]
#
#
# 80_1在最小时间戳为5时:
# 数据预测平均准确度:0.9318523769476142
# MSE:[0.073 0.063]
# RMSE:[0.27  0.251]
# MAPE:[1.014 8.297]
#
#
# 80_1在最小时间戳为30时:
# 数据预测平均准确度:0.9508170608038842
# MSE:[0.02  0.078]
# RMSE:[0.141 0.28 ]
# MAPE:[0.534 0.874]
#
#
# 80_1在最小时间戳为60时:
# 数据预测平均准确度:0.9733260866549193
# MSE:[0.015 0.038]
# RMSE:[0.123 0.195]
# MAPE:[0.647 0.87 ]
#
#
# 80_1在最小时间戳为120时:
# 数据预测平均准确度:0.9767241394754471
# MSE:[0.011 0.035]
# RMSE:[0.106 0.188]
# MAPE:[0.349 2.578]
#
#
# 80_1在最小时间戳为1440时:
# 数据预测平均准确度:0.9820657891872553
# MSE:[0.008 0.028]
# RMSE:[0.09  0.167]
# MAPE:[1.02  1.757]
#
#
# 80_2在最小时间戳为5时:
# 数据预测平均准确度:0.7894769974878059
# MSE:[0.318 0.103]
# RMSE:[0.564 0.321]
# MAPE:[0.956 1.073]
#
#
# 80_2在最小时间戳为30时:
# 数据预测平均准确度:0.8315975099684646
# MSE:[0.243 0.094]
# RMSE:[0.493 0.306]
# MAPE:[1.609 1.379]
#
#
# 80_2在最小时间戳为60时:
# 数据预测平均准确度:0.863490030181259
# MSE:[0.199 0.074]
# RMSE:[0.446 0.272]
# MAPE:[1.948 1.019]
#
#
# 80_2在最小时间戳为120时:
# 数据预测平均准确度:0.8850266434767018
# MSE:[0.175 0.055]
# RMSE:[0.418 0.235]
# MAPE:[1.026 1.023]
#
#
# 80_2在最小时间戳为1440时:
# 数据预测平均准确度:0.9342824414543343
# MSE:[0.101 0.03 ]
# RMSE:[0.318 0.174]
# MAPE:[2.247 1.615]
#
#
# 81_1在最小时间戳为5时:
# 数据预测平均准确度:0.8499214224197044
# MSE:[0.104 0.196]
# RMSE:[0.323 0.443]
# MAPE:[1.472 1.265]
#
#
# 81_1在最小时间戳为30时:
# 数据预测平均准确度:0.8899480622168543
# MSE:[0.042 0.178]
# RMSE:[0.204 0.422]
# MAPE:[4.937 1.874]
#
#
# 81_1在最小时间戳为60时:
# 数据预测平均准确度:0.912265983123302
# MSE:[0.021 0.154]
# RMSE:[0.147 0.392]
# MAPE:[0.837 2.273]
#
#
# 81_1在最小时间戳为120时:
# 数据预测平均准确度:0.9255479078013487
# MSE:[0.015 0.134]
# RMSE:[0.123 0.366]
# MAPE:[0.596 4.816]
#
#
# 81_1在最小时间戳为1440时:
# 数据预测平均准确度:0.9926911440384655
# MSE:[0.003 0.012]
# RMSE:[0.05 0.11]
# MAPE:[0.653 0.981]
#
#
# 81_2在最小时间戳为5时:
# 数据预测平均准确度:0.9536722552651218
# MSE:[0.057 0.036]
# RMSE:[0.238 0.19 ]
# MAPE:[0.984 0.944]
#
#
# 81_2在最小时间戳为30时:
# 数据预测平均准确度:0.9313865649176472
# MSE:[0.024 0.113]
# RMSE:[0.155 0.337]
# MAPE:[1.699 0.552]
#
#
# 81_2在最小时间戳为60时:
# 数据预测平均准确度:0.9567297941777835
# MSE:[0.011 0.075]
# RMSE:[0.106 0.274]
# MAPE:[0.413 0.664]
#
#
# 81_2在最小时间戳为120时:
# 数据预测平均准确度:0.9342621539576224
# MSE:[0.008 0.123]
# RMSE:[0.092 0.351]
# MAPE:[0.508 1.229]
#
#
# 81_2在最小时间戳为1440时:
# 数据预测平均准确度:0.9829535930548682
# MSE:[0.005 0.029]
# RMSE:[0.069 0.171]
# MAPE:[0.284 1.402]
#
#
# 82_1在最小时间戳为5时:
# 数据预测平均准确度:0.794918834971077
# MSE:[0.136 0.274]
# RMSE:[0.369 0.523]
# MAPE:[219.378   1.409]
#
#
# 82_1在最小时间戳为30时:
# 数据预测平均准确度:0.6154590722115746
# MSE:[0.079 0.69 ]
# RMSE:[0.281 0.831]
# MAPE:[1.604 1.801]
#
#
# 82_1在最小时间戳为60时:
# 数据预测平均准确度:0.7753587867329692
# MSE:[0.056 0.394]
# RMSE:[0.236 0.627]
# MAPE:[1.19  2.387]
#
#
# 82_1在最小时间戳为120时:
# 数据预测平均准确度:0.820379495384464
# MSE:[0.032 0.327]
# RMSE:[0.178 0.572]
# MAPE:[1.396 2.127]
#
#
# 82_1在最小时间戳为1440时:
# 数据预测平均准确度:0.6575894481345568
# MSE:[0.373 0.312]
# RMSE:[0.611 0.558]
# MAPE:[2.932 3.411]
#
#
# 82_2在最小时间戳为5时:
# 数据预测平均准确度:0.0
# MSE:[0. 0.]
# RMSE:[0.009 0.009]
# MAPE:[4.12330638e+13 4.11670996e+13]
#
#
# 82_2在最小时间戳为30时:
# 数据预测平均准确度:0.0
# MSE:[0.001 0.   ]
# RMSE:[0.022 0.022]
# MAPE:[1.00853115e+14 1.00490254e+14]
#
#
# 82_2在最小时间戳为60时:
# 数据预测平均准确度:0.0
# MSE:[0.609 2.841]
# RMSE:[0.78  1.686]
# MAPE:[3.34657413e+14 5.58250294e+14]
#
#
# 82_2在最小时间戳为120时:
# 数据预测平均准确度:0.0
# MSE:[0.654 2.864]
# RMSE:[0.809 1.692]
# MAPE:[4.82446465e+14 7.91124773e+14]
#
#
# 82_2在最小时间戳为1440时:
# 数据预测平均准确度:0.9953679594029003
# MSE:[0.007 0.002]
# RMSE:[0.086 0.044]
# MAPE:[0.254 0.252]
#
#
# 83_1在最小时间戳为5时:
# 数据预测平均准确度:0.8764971900647398
# MSE:[0.176 0.071]
# RMSE:[0.419 0.267]
# MAPE:[0.093 0.614]
#
#
# 83_1在最小时间戳为30时:
# 数据预测平均准确度:0.7299836277101572
# MSE:[0.27 0.27]
# RMSE:[0.519 0.52 ]
# MAPE:[2.302 1.441]
#
#
# 83_1在最小时间戳为60时:
# 数据预测平均准确度:0.8292531727436496
# MSE:[0.159 0.183]
# RMSE:[0.398 0.428]
# MAPE:[0.739 5.577]
#
#
# 83_1在最小时间戳为120时:
# 数据预测平均准确度:0.8835930938198888
# MSE:[0.087 0.146]
# RMSE:[0.294 0.382]
# MAPE:[0.782 1.779]
#
#
# 83_1在最小时间戳为1440时:
# 数据预测平均准确度:0.9632786367353956
# MSE:[0.025 0.049]
# RMSE:[0.157 0.221]
# MAPE:[0.942 1.048]
#
#
# 83_2在最小时间戳为5时:
# 数据预测平均准确度:0.7432947206953685
# MSE:[0.08  0.433]
# RMSE:[0.284 0.658]
# MAPE:[2.144 1.427]
#
#
# 83_2在最小时间戳为30时:
# 数据预测平均准确度:0.5136911091840806
# MSE:[0.128 0.845]
# RMSE:[0.358 0.919]
# MAPE:[1.563 9.315]
#
#
# 83_2在最小时间戳为60时:
# 数据预测平均准确度:0.5880566057183663
# MSE:[0.175 0.649]
# RMSE:[0.419 0.805]
# MAPE:[1.57  1.143]
#
#
# 83_2在最小时间戳为120时:
# 数据预测平均准确度:0.6289815404849519
# MSE:[0.19  0.552]
# RMSE:[0.436 0.743]
# MAPE:[1.058 1.534]
#
#
# 83_2在最小时间戳为1440时:
# 数据预测平均准确度:0.9049007715482942
# MSE:[0.016 0.174]
# RMSE:[0.126 0.418]
# MAPE:[0.867 2.531]
#
#
# 84_1在最小时间戳为5时:
# 数据预测平均准确度:0.9690999393770376
# MSE:[0.045 0.016]
# RMSE:[0.213 0.128]
# MAPE:[0.998 0.567]
#
#
# 84_1在最小时间戳为30时:
# 数据预测平均准确度:0.9362610354427819
# MSE:[0.019 0.109]
# RMSE:[0.137 0.33 ]
# MAPE:[1.508 0.303]
#
#
# 84_1在最小时间戳为60时:
# 数据预测平均准确度:0.9569645211326251
# MSE:[0.01  0.076]
# RMSE:[0.099 0.276]
# MAPE:[ 0.264 13.621]
#
#
# 84_1在最小时间戳为120时:
# 数据预测平均准确度:0.9677707598274139
# MSE:[0.008 0.056]
# RMSE:[0.09  0.237]
# MAPE:[0.347 0.438]
#
#
# 84_1在最小时间戳为1440时:
# 数据预测平均准确度:0.9807684183415353
# MSE:[0.004 0.034]
# RMSE:[0.063 0.186]
# MAPE:[0.657 4.719]
#
#
# 84_2在最小时间戳为5时:
# 数据预测平均准确度:0.9484493185771371
# MSE:[0.031 0.072]
# RMSE:[0.175 0.269]
# MAPE:[0.056 0.062]
#
#
# 84_2在最小时间戳为30时:
# 数据预测平均准确度:0.9471603695961529
# MSE:[0.057 0.049]
# RMSE:[0.239 0.221]
# MAPE:[0.018 0.049]
#
#
# 84_2在最小时间戳为60时:
# 数据预测平均准确度:0.7648904247654125
# MSE:[0.343 0.128]
# RMSE:[0.585 0.357]
# MAPE:[0.13  0.088]
#
#
# 84_2在最小时间戳为120时:
# 数据预测平均准确度:0.9565231697293435
# MSE:[0.045 0.042]
# RMSE:[0.212 0.205]
# MAPE:[0.124 0.084]
#
#
# 84_2在最小时间戳为1440时:
# 数据预测平均准确度:0.9886978543660921
# MSE:[0.012 0.011]
# RMSE:[0.108 0.105]
# MAPE:[0.345 0.305]
